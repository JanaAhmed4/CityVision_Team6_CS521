# %%
import requests
import time
import csv

# Foursquare API Details
API_KEY = "fsq3791aJN4+bpzTQlUFQwCW0IL44wIzjt6/JnPIhhCNwdY="
BASE_URL = "https://api.foursquare.com/v3/places/search"
HEADERS = {
    "Accept": "application/json",
    "Authorization": API_KEY
}

# Define search parameters
CITIES = {
    "Dammam": (26.3927, 50.1183),
    "Khobar": (26.2935, 50.2083),
    "Dhahran": (26.3023, 50.1513)
}
GRID_SPACING = 2.0  # Approx. 2 km spacing
SEARCH_RADIUS = 1500  # 1.5 km radius per request
MAX_RESULTS_PER_AREA = 200  # Adjust to get all businesses

# File output
RESTAURANTS_FILE = "restaurants.csv"
COFFEESHOPS_FILE = "coffeeshops.csv"

# Function to generate grid points
def generate_grid(center_lat, center_lng, spacing, range_km=15):
    """Generates grid points covering an area around a city."""
    points = []
    steps = int((range_km * 2) / spacing)
    
    for i in range(-steps // 2, steps // 2):
        for j in range(-steps // 2, steps // 2):
            lat = center_lat + (i * 0.018)  # Approx. degree change for 2km
            lng = center_lng + (j * 0.018)
            points.append((lat, lng))
    return points

# Function to fetch businesses
def fetch_businesses(lat, lng, category):
    """Fetches businesses from Foursquare API given a location and category."""
    params = {
        "ll": f"{lat},{lng}",
        "radius": SEARCH_RADIUS,
        "limit": 50,  # Foursquare max per request
        "categories": category,
        "fields": "fsq_id,name,geocodes,location,categories,rating,popularity"
    }
    
    all_places = []
    cursor = None

    while len(all_places) < MAX_RESULTS_PER_AREA:
        if cursor:
            params["cursor"] = cursor
        
        response = requests.get(BASE_URL, headers=HEADERS, params=params)
        if response.status_code != 200:
            print(f"Error fetching businesses at ({lat}, {lng}): {response.status_code}")
            break
        
        data = response.json()
        places = data.get("results", [])
        all_places.extend(places)
        
        cursor = data.get("context", {}).get("next")
        if not cursor:
            break  # No more results
        
        time.sleep(1)  # Prevent rate limiting
    
    return all_places[:MAX_RESULTS_PER_AREA]

# Function to save data
def save_to_csv(data, filename):
    """Saves data to CSV file."""
    header = ["Business ID", "Name", "Latitude", "Longitude", "Category", "Rating", "Popularity"]
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(header)
        writer.writerows(data)

# Main function
def main():
    restaurants_data = []
    coffeeshops_data = []

    for city, (center_lat, center_lng) in CITIES.items():
        print(f"Searching in {city}...")
        grid_points = generate_grid(center_lat, center_lng, GRID_SPACING)

        for lat, lng in grid_points:
            print(f"Fetching data for ({lat}, {lng})...")
            
            # Fetch Restaurants
            restaurants = fetch_businesses(lat, lng, "13065")
            for place in restaurants:
                restaurants_data.append([
                    place.get("fsq_id", "N/A"),
                    place.get("name", "N/A"),
                    place.get("geocodes", {}).get("main", {}).get("latitude", "N/A"),
                    place.get("geocodes", {}).get("main", {}).get("longitude", "N/A"),
                    place.get("categories", [{}])[0].get("name", "N/A"),
                    place.get("rating", "No rating"),
                    place.get("popularity", "No popularity data")
                ])
            
            # Fetch Coffee Shops
            coffeeshops = fetch_businesses(lat, lng, "13032")
            for place in coffeeshops:
                coffeeshops_data.append([
                    place.get("fsq_id", "N/A"),
                    place.get("name", "N/A"),
                    place.get("geocodes", {}).get("main", {}).get("latitude", "N/A"),
                    place.get("geocodes", {}).get("main", {}).get("longitude", "N/A"),
                    place.get("categories", [{}])[0].get("name", "N/A"),
                    place.get("rating", "No rating"),
                    place.get("popularity", "No popularity data")
                ])
            
            time.sleep(1)  # Avoid API rate limit
    
    # Save to CSV
    save_to_csv(restaurants_data, RESTAURANTS_FILE)
    save_to_csv(coffeeshops_data, COFFEESHOPS_FILE)
    print("✅ Data collection complete! Check the CSV files.")

if __name__ == "__main__":
    main()
# Out:
# Searching in Dammam...
# Fetching data for (26.248700000000003, 49.9743)...
# Fetching data for (26.248700000000003, 49.9923)...
# Fetching data for (26.248700000000003, 50.0103)...
# Fetching data for (26.248700000000003, 50.028299999999994)...
# Fetching data for (26.248700000000003, 50.046299999999995)...
# Fetching data for (26.248700000000003, 50.064299999999996)...
# Fetching data for (26.248700000000003, 50.0823)...
# Fetching data for (26.248700000000003, 50.1003)...
# Fetching data for (26.248700000000003, 50.1183)...
# Fetching data for (26.248700000000003, 50.1363)...
# Fetching data for (26.248700000000003, 50.1543)...
# Fetching data for (26.248700000000003, 50.1723)...
# Fetching data for (26.248700000000003, 50.1903)...
# Fetching data for (26.248700000000003, 50.2083)...
# Fetching data for (26.248700000000003, 50.226299999999995)...
# Fetching data for (26.2667, 49.9743)...
# Fetching data for (26.2667, 49.9923)...
# Fetching data for (26.2667, 50.0103)...
# Fetching data for (26.2667, 50.028299999999994)...
# Fetching data for (26.2667, 50.046299999999995)...
# Fetching data for (26.2667, 50.064299999999996)...
# Fetching data for (26.2667, 50.0823)...
# Fetching data for (26.2667, 50.1003)...
# Fetching data for (26.2667, 50.1183)...
# Fetching data for (26.2667, 50.1363)...
# Fetching data for (26.2667, 50.1543)...
# Fetching data for (26.2667, 50.1723)...
# Fetching data for (26.2667, 50.1903)...
# Fetching data for (26.2667, 50.2083)...
# Fetching data for (26.2667, 50.226299999999995)...
# Fetching data for (26.2847, 49.9743)...
# Fetching data for (26.2847, 49.9923)...
# Fetching data for (26.2847, 50.0103)...
# Fetching data for (26.2847, 50.028299999999994)...
# Fetching data for (26.2847, 50.046299999999995)...
# Fetching data for (26.2847, 50.064299999999996)...
# Fetching data for (26.2847, 50.0823)...
# Fetching data for (26.2847, 50.1003)...
# Fetching data for (26.2847, 50.1183)...
# Fetching data for (26.2847, 50.1363)...
# Fetching data for (26.2847, 50.1543)...
# Fetching data for (26.2847, 50.1723)...
# Fetching data for (26.2847, 50.1903)...
# Fetching data for (26.2847, 50.2083)...
# Fetching data for (26.2847, 50.226299999999995)...
# Fetching data for (26.3027, 49.9743)...
# Fetching data for (26.3027, 49.9923)...
# Fetching data for (26.3027, 50.0103)...
# Fetching data for (26.3027, 50.028299999999994)...
# Fetching data for (26.3027, 50.046299999999995)...
# Fetching data for (26.3027, 50.064299999999996)...
# Fetching data for (26.3027, 50.0823)...
# Fetching data for (26.3027, 50.1003)...
# Fetching data for (26.3027, 50.1183)...
# Fetching data for (26.3027, 50.1363)...
# Fetching data for (26.3027, 50.1543)...
# Fetching data for (26.3027, 50.1723)...
# Fetching data for (26.3027, 50.1903)...
# Fetching data for (26.3027, 50.2083)...
# Fetching data for (26.3027, 50.226299999999995)...
# Fetching data for (26.320700000000002, 49.9743)...
# Fetching data for (26.320700000000002, 49.9923)...
# Fetching data for (26.320700000000002, 50.0103)...
# Fetching data for (26.320700000000002, 50.028299999999994)...
# Fetching data for (26.320700000000002, 50.046299999999995)...
# Fetching data for (26.320700000000002, 50.064299999999996)...
# Fetching data for (26.320700000000002, 50.0823)...
# Fetching data for (26.320700000000002, 50.1003)...
# Fetching data for (26.320700000000002, 50.1183)...
# Fetching data for (26.320700000000002, 50.1363)...
# Fetching data for (26.320700000000002, 50.1543)...
# Fetching data for (26.320700000000002, 50.1723)...
# Fetching data for (26.320700000000002, 50.1903)...
# Fetching data for (26.320700000000002, 50.2083)...
# Fetching data for (26.320700000000002, 50.226299999999995)...
# Fetching data for (26.338700000000003, 49.9743)...
# Fetching data for (26.338700000000003, 49.9923)...
# Fetching data for (26.338700000000003, 50.0103)...
# Fetching data for (26.338700000000003, 50.028299999999994)...
# Fetching data for (26.338700000000003, 50.046299999999995)...
# Fetching data for (26.338700000000003, 50.064299999999996)...
# Fetching data for (26.338700000000003, 50.0823)...
# Fetching data for (26.338700000000003, 50.1003)...
# Fetching data for (26.338700000000003, 50.1183)...
# Fetching data for (26.338700000000003, 50.1363)...
# Fetching data for (26.338700000000003, 50.1543)...
# Fetching data for (26.338700000000003, 50.1723)...
# Fetching data for (26.338700000000003, 50.1903)...
# Fetching data for (26.338700000000003, 50.2083)...
# Fetching data for (26.338700000000003, 50.226299999999995)...
# Fetching data for (26.3567, 49.9743)...
# Fetching data for (26.3567, 49.9923)...
# Fetching data for (26.3567, 50.0103)...
# Fetching data for (26.3567, 50.028299999999994)...
# Fetching data for (26.3567, 50.046299999999995)...
# Fetching data for (26.3567, 50.064299999999996)...
# Fetching data for (26.3567, 50.0823)...
# Fetching data for (26.3567, 50.1003)...
# Fetching data for (26.3567, 50.1183)...
# Fetching data for (26.3567, 50.1363)...
# Fetching data for (26.3567, 50.1543)...
# Fetching data for (26.3567, 50.1723)...
# Fetching data for (26.3567, 50.1903)...
# Fetching data for (26.3567, 50.2083)...
# Fetching data for (26.3567, 50.226299999999995)...
# Fetching data for (26.3747, 49.9743)...
# Fetching data for (26.3747, 49.9923)...
# Fetching data for (26.3747, 50.0103)...
# Fetching data for (26.3747, 50.028299999999994)...
# Fetching data for (26.3747, 50.046299999999995)...
# Fetching data for (26.3747, 50.064299999999996)...
# Fetching data for (26.3747, 50.0823)...
# Fetching data for (26.3747, 50.1003)...
# Fetching data for (26.3747, 50.1183)...
# Fetching data for (26.3747, 50.1363)...
# Fetching data for (26.3747, 50.1543)...
# Fetching data for (26.3747, 50.1723)...
# Fetching data for (26.3747, 50.1903)...
# Fetching data for (26.3747, 50.2083)...
# Fetching data for (26.3747, 50.226299999999995)...
# Fetching data for (26.3927, 49.9743)...
# Fetching data for (26.3927, 49.9923)...
# Fetching data for (26.3927, 50.0103)...
# Fetching data for (26.3927, 50.028299999999994)...
# Fetching data for (26.3927, 50.046299999999995)...
# Fetching data for (26.3927, 50.064299999999996)...
# Fetching data for (26.3927, 50.0823)...
# Fetching data for (26.3927, 50.1003)...
# Fetching data for (26.3927, 50.1183)...
# Fetching data for (26.3927, 50.1363)...
# Fetching data for (26.3927, 50.1543)...
# Fetching data for (26.3927, 50.1723)...
# Fetching data for (26.3927, 50.1903)...
# Fetching data for (26.3927, 50.2083)...
# Fetching data for (26.3927, 50.226299999999995)...
# Fetching data for (26.410700000000002, 49.9743)...
# Fetching data for (26.410700000000002, 49.9923)...
# Fetching data for (26.410700000000002, 50.0103)...
# Fetching data for (26.410700000000002, 50.028299999999994)...
# Fetching data for (26.410700000000002, 50.046299999999995)...
# Fetching data for (26.410700000000002, 50.064299999999996)...
# Fetching data for (26.410700000000002, 50.0823)...
# Fetching data for (26.410700000000002, 50.1003)...
# Fetching data for (26.410700000000002, 50.1183)...
# Fetching data for (26.410700000000002, 50.1363)...
# Fetching data for (26.410700000000002, 50.1543)...
# Fetching data for (26.410700000000002, 50.1723)...
# Fetching data for (26.410700000000002, 50.1903)...
# Fetching data for (26.410700000000002, 50.2083)...
# Fetching data for (26.410700000000002, 50.226299999999995)...
# Fetching data for (26.428700000000003, 49.9743)...
# Fetching data for (26.428700000000003, 49.9923)...
# Fetching data for (26.428700000000003, 50.0103)...
# Fetching data for (26.428700000000003, 50.028299999999994)...
# Fetching data for (26.428700000000003, 50.046299999999995)...
# Fetching data for (26.428700000000003, 50.064299999999996)...
# Fetching data for (26.428700000000003, 50.0823)...
# Fetching data for (26.428700000000003, 50.1003)...
# Fetching data for (26.428700000000003, 50.1183)...
# Fetching data for (26.428700000000003, 50.1363)...
# Fetching data for (26.428700000000003, 50.1543)...
# Fetching data for (26.428700000000003, 50.1723)...
# Fetching data for (26.428700000000003, 50.1903)...
# Fetching data for (26.428700000000003, 50.2083)...
# Fetching data for (26.428700000000003, 50.226299999999995)...
# Fetching data for (26.4467, 49.9743)...
# Fetching data for (26.4467, 49.9923)...
# Fetching data for (26.4467, 50.0103)...
# Fetching data for (26.4467, 50.028299999999994)...
# Fetching data for (26.4467, 50.046299999999995)...
# Fetching data for (26.4467, 50.064299999999996)...
# Fetching data for (26.4467, 50.0823)...
# Fetching data for (26.4467, 50.1003)...
# Fetching data for (26.4467, 50.1183)...
# Fetching data for (26.4467, 50.1363)...
# Fetching data for (26.4467, 50.1543)...
# Fetching data for (26.4467, 50.1723)...
# Fetching data for (26.4467, 50.1903)...
# Fetching data for (26.4467, 50.2083)...
# Fetching data for (26.4467, 50.226299999999995)...
# Fetching data for (26.4647, 49.9743)...
# Fetching data for (26.4647, 49.9923)...
# Fetching data for (26.4647, 50.0103)...
# Fetching data for (26.4647, 50.028299999999994)...
# Fetching data for (26.4647, 50.046299999999995)...
# Fetching data for (26.4647, 50.064299999999996)...
# Fetching data for (26.4647, 50.0823)...
# Fetching data for (26.4647, 50.1003)...
# Fetching data for (26.4647, 50.1183)...
# Fetching data for (26.4647, 50.1363)...
# Fetching data for (26.4647, 50.1543)...
# Fetching data for (26.4647, 50.1723)...
# Fetching data for (26.4647, 50.1903)...
# Fetching data for (26.4647, 50.2083)...
# Fetching data for (26.4647, 50.226299999999995)...
# Fetching data for (26.4827, 49.9743)...
# Fetching data for (26.4827, 49.9923)...
# Fetching data for (26.4827, 50.0103)...
# Fetching data for (26.4827, 50.028299999999994)...
# Fetching data for (26.4827, 50.046299999999995)...
# Fetching data for (26.4827, 50.064299999999996)...
# Fetching data for (26.4827, 50.0823)...
# Fetching data for (26.4827, 50.1003)...
# Fetching data for (26.4827, 50.1183)...
# Fetching data for (26.4827, 50.1363)...
# Fetching data for (26.4827, 50.1543)...
# Fetching data for (26.4827, 50.1723)...
# Fetching data for (26.4827, 50.1903)...
# Fetching data for (26.4827, 50.2083)...
# Fetching data for (26.4827, 50.226299999999995)...
# Fetching data for (26.500700000000002, 49.9743)...
# Fetching data for (26.500700000000002, 49.9923)...
# Fetching data for (26.500700000000002, 50.0103)...
# Fetching data for (26.500700000000002, 50.028299999999994)...
# Fetching data for (26.500700000000002, 50.046299999999995)...
# Fetching data for (26.500700000000002, 50.064299999999996)...
# Fetching data for (26.500700000000002, 50.0823)...
# Fetching data for (26.500700000000002, 50.1003)...
# Fetching data for (26.500700000000002, 50.1183)...
# Fetching data for (26.500700000000002, 50.1363)...
# Fetching data for (26.500700000000002, 50.1543)...
# Fetching data for (26.500700000000002, 50.1723)...
# Fetching data for (26.500700000000002, 50.1903)...
# Fetching data for (26.500700000000002, 50.2083)...
# Fetching data for (26.500700000000002, 50.226299999999995)...
# Searching in Khobar...
# Fetching data for (26.149500000000003, 50.0643)...
# Fetching data for (26.149500000000003, 50.082300000000004)...
# Fetching data for (26.149500000000003, 50.100300000000004)...
# Fetching data for (26.149500000000003, 50.1183)...
# Fetching data for (26.149500000000003, 50.1363)...
# Fetching data for (26.149500000000003, 50.1543)...
# Fetching data for (26.149500000000003, 50.1723)...
# Fetching data for (26.149500000000003, 50.1903)...
# Fetching data for (26.149500000000003, 50.2083)...
# Fetching data for (26.149500000000003, 50.2263)...
# Fetching data for (26.149500000000003, 50.2443)...
# Fetching data for (26.149500000000003, 50.2623)...
# Fetching data for (26.149500000000003, 50.280300000000004)...
# Fetching data for (26.149500000000003, 50.298300000000005)...
# Fetching data for (26.149500000000003, 50.3163)...
# Fetching data for (26.1675, 50.0643)...
# Fetching data for (26.1675, 50.082300000000004)...
# Fetching data for (26.1675, 50.100300000000004)...
# Fetching data for (26.1675, 50.1183)...
# Fetching data for (26.1675, 50.1363)...
# Fetching data for (26.1675, 50.1543)...
# Fetching data for (26.1675, 50.1723)...
# Fetching data for (26.1675, 50.1903)...
# Fetching data for (26.1675, 50.2083)...
# Fetching data for (26.1675, 50.2263)...
# Fetching data for (26.1675, 50.2443)...
# Fetching data for (26.1675, 50.2623)...
# Fetching data for (26.1675, 50.280300000000004)...
# Fetching data for (26.1675, 50.298300000000005)...
# Fetching data for (26.1675, 50.3163)...
# Fetching data for (26.1855, 50.0643)...
# Fetching data for (26.1855, 50.082300000000004)...
# Fetching data for (26.1855, 50.100300000000004)...
# Fetching data for (26.1855, 50.1183)...
# Fetching data for (26.1855, 50.1363)...
# Fetching data for (26.1855, 50.1543)...
# Fetching data for (26.1855, 50.1723)...
# Fetching data for (26.1855, 50.1903)...
# Fetching data for (26.1855, 50.2083)...
# Fetching data for (26.1855, 50.2263)...
# Fetching data for (26.1855, 50.2443)...
# Fetching data for (26.1855, 50.2623)...
# Fetching data for (26.1855, 50.280300000000004)...
# Fetching data for (26.1855, 50.298300000000005)...
# Fetching data for (26.1855, 50.3163)...
# Fetching data for (26.203500000000002, 50.0643)...
# Fetching data for (26.203500000000002, 50.082300000000004)...
# Fetching data for (26.203500000000002, 50.100300000000004)...
# Fetching data for (26.203500000000002, 50.1183)...
# Fetching data for (26.203500000000002, 50.1363)...
# Fetching data for (26.203500000000002, 50.1543)...
# Fetching data for (26.203500000000002, 50.1723)...
# Fetching data for (26.203500000000002, 50.1903)...
# Fetching data for (26.203500000000002, 50.2083)...
# Fetching data for (26.203500000000002, 50.2263)...
# Fetching data for (26.203500000000002, 50.2443)...
# Fetching data for (26.203500000000002, 50.2623)...
# Fetching data for (26.203500000000002, 50.280300000000004)...
# Fetching data for (26.203500000000002, 50.298300000000005)...
# Fetching data for (26.203500000000002, 50.3163)...
# Fetching data for (26.221500000000002, 50.0643)...
# Fetching data for (26.221500000000002, 50.082300000000004)...
# Fetching data for (26.221500000000002, 50.100300000000004)...
# Fetching data for (26.221500000000002, 50.1183)...
# Fetching data for (26.221500000000002, 50.1363)...
# Fetching data for (26.221500000000002, 50.1543)...
# Fetching data for (26.221500000000002, 50.1723)...
# Fetching data for (26.221500000000002, 50.1903)...
# Fetching data for (26.221500000000002, 50.2083)...
# Fetching data for (26.221500000000002, 50.2263)...
# Fetching data for (26.221500000000002, 50.2443)...
# Fetching data for (26.221500000000002, 50.2623)...
# Fetching data for (26.221500000000002, 50.280300000000004)...
# Fetching data for (26.221500000000002, 50.298300000000005)...
# Fetching data for (26.221500000000002, 50.3163)...
# Fetching data for (26.239500000000003, 50.0643)...
# Fetching data for (26.239500000000003, 50.082300000000004)...
# Fetching data for (26.239500000000003, 50.100300000000004)...
# Fetching data for (26.239500000000003, 50.1183)...
# Fetching data for (26.239500000000003, 50.1363)...
# Fetching data for (26.239500000000003, 50.1543)...
# Fetching data for (26.239500000000003, 50.1723)...
# Fetching data for (26.239500000000003, 50.1903)...
# Fetching data for (26.239500000000003, 50.2083)...
# Fetching data for (26.239500000000003, 50.2263)...
# Fetching data for (26.239500000000003, 50.2443)...
# Fetching data for (26.239500000000003, 50.2623)...
# Fetching data for (26.239500000000003, 50.280300000000004)...
# Fetching data for (26.239500000000003, 50.298300000000005)...
# Fetching data for (26.239500000000003, 50.3163)...
# Fetching data for (26.2575, 50.0643)...
# Fetching data for (26.2575, 50.082300000000004)...
# Fetching data for (26.2575, 50.100300000000004)...
# Fetching data for (26.2575, 50.1183)...
# Fetching data for (26.2575, 50.1363)...
# Fetching data for (26.2575, 50.1543)...
# Fetching data for (26.2575, 50.1723)...
# Fetching data for (26.2575, 50.1903)...
# Fetching data for (26.2575, 50.2083)...
# Fetching data for (26.2575, 50.2263)...
# Fetching data for (26.2575, 50.2443)...
# Fetching data for (26.2575, 50.2623)...
# Fetching data for (26.2575, 50.280300000000004)...
# Fetching data for (26.2575, 50.298300000000005)...
# Fetching data for (26.2575, 50.3163)...
# Fetching data for (26.2755, 50.0643)...
# Fetching data for (26.2755, 50.082300000000004)...
# Fetching data for (26.2755, 50.100300000000004)...
# Fetching data for (26.2755, 50.1183)...
# Fetching data for (26.2755, 50.1363)...
# Fetching data for (26.2755, 50.1543)...
# Fetching data for (26.2755, 50.1723)...
# Fetching data for (26.2755, 50.1903)...
# Fetching data for (26.2755, 50.2083)...
# Fetching data for (26.2755, 50.2263)...
# Fetching data for (26.2755, 50.2443)...
# Fetching data for (26.2755, 50.2623)...
# Fetching data for (26.2755, 50.280300000000004)...
# Fetching data for (26.2755, 50.298300000000005)...
# Fetching data for (26.2755, 50.3163)...
# Fetching data for (26.2935, 50.0643)...
# Fetching data for (26.2935, 50.082300000000004)...
# Fetching data for (26.2935, 50.100300000000004)...
# Fetching data for (26.2935, 50.1183)...
# Fetching data for (26.2935, 50.1363)...
# Fetching data for (26.2935, 50.1543)...
# Fetching data for (26.2935, 50.1723)...
# Fetching data for (26.2935, 50.1903)...
# Fetching data for (26.2935, 50.2083)...
# Fetching data for (26.2935, 50.2263)...
# Fetching data for (26.2935, 50.2443)...
# Fetching data for (26.2935, 50.2623)...
# Fetching data for (26.2935, 50.280300000000004)...
# Fetching data for (26.2935, 50.298300000000005)...
# Fetching data for (26.2935, 50.3163)...
# Fetching data for (26.311500000000002, 50.0643)...
# Fetching data for (26.311500000000002, 50.082300000000004)...
# Fetching data for (26.311500000000002, 50.100300000000004)...
# Fetching data for (26.311500000000002, 50.1183)...
# Fetching data for (26.311500000000002, 50.1363)...
# Fetching data for (26.311500000000002, 50.1543)...
# Fetching data for (26.311500000000002, 50.1723)...
# Fetching data for (26.311500000000002, 50.1903)...
# Fetching data for (26.311500000000002, 50.2083)...
# Fetching data for (26.311500000000002, 50.2263)...
# Fetching data for (26.311500000000002, 50.2443)...
# Fetching data for (26.311500000000002, 50.2623)...
# Fetching data for (26.311500000000002, 50.280300000000004)...
# Fetching data for (26.311500000000002, 50.298300000000005)...
# Fetching data for (26.311500000000002, 50.3163)...
# Fetching data for (26.329500000000003, 50.0643)...
# Fetching data for (26.329500000000003, 50.082300000000004)...
# Fetching data for (26.329500000000003, 50.100300000000004)...
# Fetching data for (26.329500000000003, 50.1183)...
# Fetching data for (26.329500000000003, 50.1363)...
# Fetching data for (26.329500000000003, 50.1543)...
# Fetching data for (26.329500000000003, 50.1723)...
# Fetching data for (26.329500000000003, 50.1903)...
# Fetching data for (26.329500000000003, 50.2083)...
# Fetching data for (26.329500000000003, 50.2263)...
# Fetching data for (26.329500000000003, 50.2443)...
# Fetching data for (26.329500000000003, 50.2623)...
# Fetching data for (26.329500000000003, 50.280300000000004)...
# Fetching data for (26.329500000000003, 50.298300000000005)...
# Fetching data for (26.329500000000003, 50.3163)...
# Fetching data for (26.3475, 50.0643)...
# Fetching data for (26.3475, 50.082300000000004)...
# Fetching data for (26.3475, 50.100300000000004)...
# Fetching data for (26.3475, 50.1183)...
# Fetching data for (26.3475, 50.1363)...
# Fetching data for (26.3475, 50.1543)...
# Fetching data for (26.3475, 50.1723)...
# Fetching data for (26.3475, 50.1903)...
# Fetching data for (26.3475, 50.2083)...
# Fetching data for (26.3475, 50.2263)...
# Fetching data for (26.3475, 50.2443)...
# Fetching data for (26.3475, 50.2623)...
# Fetching data for (26.3475, 50.280300000000004)...
# Fetching data for (26.3475, 50.298300000000005)...
# Fetching data for (26.3475, 50.3163)...
# Fetching data for (26.3655, 50.0643)...
# Fetching data for (26.3655, 50.082300000000004)...
# Fetching data for (26.3655, 50.100300000000004)...
# Fetching data for (26.3655, 50.1183)...
# Fetching data for (26.3655, 50.1363)...
# Fetching data for (26.3655, 50.1543)...
# Fetching data for (26.3655, 50.1723)...
# Fetching data for (26.3655, 50.1903)...
# Fetching data for (26.3655, 50.2083)...
# Fetching data for (26.3655, 50.2263)...
# Fetching data for (26.3655, 50.2443)...
# Fetching data for (26.3655, 50.2623)...
# Fetching data for (26.3655, 50.280300000000004)...
# Fetching data for (26.3655, 50.298300000000005)...
# Fetching data for (26.3655, 50.3163)...
# Fetching data for (26.3835, 50.0643)...
# Fetching data for (26.3835, 50.082300000000004)...
# Fetching data for (26.3835, 50.100300000000004)...
# Fetching data for (26.3835, 50.1183)...
# Fetching data for (26.3835, 50.1363)...
# Fetching data for (26.3835, 50.1543)...
# Fetching data for (26.3835, 50.1723)...
# Fetching data for (26.3835, 50.1903)...
# Fetching data for (26.3835, 50.2083)...
# Fetching data for (26.3835, 50.2263)...
# Fetching data for (26.3835, 50.2443)...
# Fetching data for (26.3835, 50.2623)...
# Fetching data for (26.3835, 50.280300000000004)...
# Fetching data for (26.3835, 50.298300000000005)...
# Fetching data for (26.3835, 50.3163)...
# Fetching data for (26.401500000000002, 50.0643)...
# Fetching data for (26.401500000000002, 50.082300000000004)...
# Fetching data for (26.401500000000002, 50.100300000000004)...
# Fetching data for (26.401500000000002, 50.1183)...
# Fetching data for (26.401500000000002, 50.1363)...
# Fetching data for (26.401500000000002, 50.1543)...
# Fetching data for (26.401500000000002, 50.1723)...
# Fetching data for (26.401500000000002, 50.1903)...
# Fetching data for (26.401500000000002, 50.2083)...
# Fetching data for (26.401500000000002, 50.2263)...
# Fetching data for (26.401500000000002, 50.2443)...
# Fetching data for (26.401500000000002, 50.2623)...
# Fetching data for (26.401500000000002, 50.280300000000004)...
# Fetching data for (26.401500000000002, 50.298300000000005)...
# Fetching data for (26.401500000000002, 50.3163)...
# Searching in Dhahran...
# Fetching data for (26.1583, 50.0073)...
# Fetching data for (26.1583, 50.0253)...
# Fetching data for (26.1583, 50.0433)...
# Fetching data for (26.1583, 50.061299999999996)...
# Fetching data for (26.1583, 50.079299999999996)...
# Fetching data for (26.1583, 50.0973)...
# Fetching data for (26.1583, 50.1153)...
# Fetching data for (26.1583, 50.1333)...
# Fetching data for (26.1583, 50.1513)...
# Fetching data for (26.1583, 50.1693)...
# Fetching data for (26.1583, 50.1873)...
# Fetching data for (26.1583, 50.2053)...
# Fetching data for (26.1583, 50.2233)...
# Fetching data for (26.1583, 50.2413)...
# Fetching data for (26.1583, 50.259299999999996)...
# Fetching data for (26.176299999999998, 50.0073)...
# Fetching data for (26.176299999999998, 50.0253)...
# Fetching data for (26.176299999999998, 50.0433)...
# Fetching data for (26.176299999999998, 50.061299999999996)...
# Fetching data for (26.176299999999998, 50.079299999999996)...
# Fetching data for (26.176299999999998, 50.0973)...
# Fetching data for (26.176299999999998, 50.1153)...
# Fetching data for (26.176299999999998, 50.1333)...
# Fetching data for (26.176299999999998, 50.1513)...
# Fetching data for (26.176299999999998, 50.1693)...
# Fetching data for (26.176299999999998, 50.1873)...
# Fetching data for (26.176299999999998, 50.2053)...
# Fetching data for (26.176299999999998, 50.2233)...
# Fetching data for (26.176299999999998, 50.2413)...
# Fetching data for (26.176299999999998, 50.259299999999996)...
# Fetching data for (26.1943, 50.0073)...
# Fetching data for (26.1943, 50.0253)...
# Fetching data for (26.1943, 50.0433)...
# Fetching data for (26.1943, 50.061299999999996)...
# Fetching data for (26.1943, 50.079299999999996)...
# Fetching data for (26.1943, 50.0973)...
# Fetching data for (26.1943, 50.1153)...
# Fetching data for (26.1943, 50.1333)...
# Fetching data for (26.1943, 50.1513)...
# Fetching data for (26.1943, 50.1693)...
# Fetching data for (26.1943, 50.1873)...
# Fetching data for (26.1943, 50.2053)...
# Fetching data for (26.1943, 50.2233)...
# Fetching data for (26.1943, 50.2413)...
# Fetching data for (26.1943, 50.259299999999996)...
# Fetching data for (26.2123, 50.0073)...
# Fetching data for (26.2123, 50.0253)...
# Fetching data for (26.2123, 50.0433)...
# Fetching data for (26.2123, 50.061299999999996)...
# Fetching data for (26.2123, 50.079299999999996)...
# Fetching data for (26.2123, 50.0973)...
# Fetching data for (26.2123, 50.1153)...
# Fetching data for (26.2123, 50.1333)...
# Fetching data for (26.2123, 50.1513)...
# Fetching data for (26.2123, 50.1693)...
# Fetching data for (26.2123, 50.1873)...
# Fetching data for (26.2123, 50.2053)...
# Fetching data for (26.2123, 50.2233)...
# Fetching data for (26.2123, 50.2413)...
# Fetching data for (26.2123, 50.259299999999996)...
# Fetching data for (26.2303, 50.0073)...
# Fetching data for (26.2303, 50.0253)...
# Fetching data for (26.2303, 50.0433)...
# Fetching data for (26.2303, 50.061299999999996)...
# Fetching data for (26.2303, 50.079299999999996)...
# Fetching data for (26.2303, 50.0973)...
# Fetching data for (26.2303, 50.1153)...
# Fetching data for (26.2303, 50.1333)...
# Fetching data for (26.2303, 50.1513)...
# Fetching data for (26.2303, 50.1693)...
# Fetching data for (26.2303, 50.1873)...
# Fetching data for (26.2303, 50.2053)...
# Fetching data for (26.2303, 50.2233)...
# Fetching data for (26.2303, 50.2413)...
# Fetching data for (26.2303, 50.259299999999996)...
# Fetching data for (26.2483, 50.0073)...
# Fetching data for (26.2483, 50.0253)...
# Fetching data for (26.2483, 50.0433)...
# Fetching data for (26.2483, 50.061299999999996)...
# Fetching data for (26.2483, 50.079299999999996)...
# Fetching data for (26.2483, 50.0973)...
# Fetching data for (26.2483, 50.1153)...
# Fetching data for (26.2483, 50.1333)...
# Fetching data for (26.2483, 50.1513)...
# Fetching data for (26.2483, 50.1693)...
# Fetching data for (26.2483, 50.1873)...
# Fetching data for (26.2483, 50.2053)...
# Fetching data for (26.2483, 50.2233)...
# Fetching data for (26.2483, 50.2413)...
# Fetching data for (26.2483, 50.259299999999996)...
# Fetching data for (26.266299999999998, 50.0073)...
# Fetching data for (26.266299999999998, 50.0253)...
# Fetching data for (26.266299999999998, 50.0433)...
# Fetching data for (26.266299999999998, 50.061299999999996)...
# Fetching data for (26.266299999999998, 50.079299999999996)...
# Fetching data for (26.266299999999998, 50.0973)...
# Fetching data for (26.266299999999998, 50.1153)...
# Fetching data for (26.266299999999998, 50.1333)...
# Fetching data for (26.266299999999998, 50.1513)...
# Fetching data for (26.266299999999998, 50.1693)...
# Fetching data for (26.266299999999998, 50.1873)...
# Fetching data for (26.266299999999998, 50.2053)...
# Fetching data for (26.266299999999998, 50.2233)...
# Fetching data for (26.266299999999998, 50.2413)...
# Fetching data for (26.266299999999998, 50.259299999999996)...
# Fetching data for (26.284299999999998, 50.0073)...
# Fetching data for (26.284299999999998, 50.0253)...
# Fetching data for (26.284299999999998, 50.0433)...
# Fetching data for (26.284299999999998, 50.061299999999996)...
# Fetching data for (26.284299999999998, 50.079299999999996)...
# Fetching data for (26.284299999999998, 50.0973)...
# Fetching data for (26.284299999999998, 50.1153)...
# Fetching data for (26.284299999999998, 50.1333)...
# Fetching data for (26.284299999999998, 50.1513)...
# Fetching data for (26.284299999999998, 50.1693)...
# Fetching data for (26.284299999999998, 50.1873)...
# Fetching data for (26.284299999999998, 50.2053)...
# Fetching data for (26.284299999999998, 50.2233)...
# Fetching data for (26.284299999999998, 50.2413)...
# Fetching data for (26.284299999999998, 50.259299999999996)...
# Fetching data for (26.3023, 50.0073)...
# Fetching data for (26.3023, 50.0253)...
# Fetching data for (26.3023, 50.0433)...
# Fetching data for (26.3023, 50.061299999999996)...
# Fetching data for (26.3023, 50.079299999999996)...
# Fetching data for (26.3023, 50.0973)...
# Fetching data for (26.3023, 50.1153)...
# Fetching data for (26.3023, 50.1333)...
# Fetching data for (26.3023, 50.1513)...
# Fetching data for (26.3023, 50.1693)...
# Fetching data for (26.3023, 50.1873)...
# Fetching data for (26.3023, 50.2053)...
# Fetching data for (26.3023, 50.2233)...
# Fetching data for (26.3023, 50.2413)...
# Fetching data for (26.3023, 50.259299999999996)...
# Fetching data for (26.3203, 50.0073)...
# Fetching data for (26.3203, 50.0253)...
# Fetching data for (26.3203, 50.0433)...
# Fetching data for (26.3203, 50.061299999999996)...
# Fetching data for (26.3203, 50.079299999999996)...
# Fetching data for (26.3203, 50.0973)...
# Fetching data for (26.3203, 50.1153)...
# Fetching data for (26.3203, 50.1333)...
# Fetching data for (26.3203, 50.1513)...
# Fetching data for (26.3203, 50.1693)...
# Fetching data for (26.3203, 50.1873)...
# Fetching data for (26.3203, 50.2053)...
# Fetching data for (26.3203, 50.2233)...
# Fetching data for (26.3203, 50.2413)...
# Fetching data for (26.3203, 50.259299999999996)...
# Fetching data for (26.3383, 50.0073)...
# Fetching data for (26.3383, 50.0253)...
# Fetching data for (26.3383, 50.0433)...
# Fetching data for (26.3383, 50.061299999999996)...
# Fetching data for (26.3383, 50.079299999999996)...
# Fetching data for (26.3383, 50.0973)...
# Fetching data for (26.3383, 50.1153)...
# Fetching data for (26.3383, 50.1333)...
# Fetching data for (26.3383, 50.1513)...
# Fetching data for (26.3383, 50.1693)...
# Fetching data for (26.3383, 50.1873)...
# Fetching data for (26.3383, 50.2053)...
# Fetching data for (26.3383, 50.2233)...
# Fetching data for (26.3383, 50.2413)...
# Fetching data for (26.3383, 50.259299999999996)...
# Fetching data for (26.356299999999997, 50.0073)...
# Fetching data for (26.356299999999997, 50.0253)...
# Fetching data for (26.356299999999997, 50.0433)...
# Fetching data for (26.356299999999997, 50.061299999999996)...
# Fetching data for (26.356299999999997, 50.079299999999996)...
# Fetching data for (26.356299999999997, 50.0973)...
# Fetching data for (26.356299999999997, 50.1153)...
# Fetching data for (26.356299999999997, 50.1333)...
# Fetching data for (26.356299999999997, 50.1513)...
# Fetching data for (26.356299999999997, 50.1693)...
# Fetching data for (26.356299999999997, 50.1873)...
# Fetching data for (26.356299999999997, 50.2053)...
# Fetching data for (26.356299999999997, 50.2233)...
# Fetching data for (26.356299999999997, 50.2413)...
# Fetching data for (26.356299999999997, 50.259299999999996)...
# Fetching data for (26.374299999999998, 50.0073)...
# Fetching data for (26.374299999999998, 50.0253)...
# Fetching data for (26.374299999999998, 50.0433)...
# Fetching data for (26.374299999999998, 50.061299999999996)...
# Fetching data for (26.374299999999998, 50.079299999999996)...
# Fetching data for (26.374299999999998, 50.0973)...
# Fetching data for (26.374299999999998, 50.1153)...
# Fetching data for (26.374299999999998, 50.1333)...
# Fetching data for (26.374299999999998, 50.1513)...
# Fetching data for (26.374299999999998, 50.1693)...
# Fetching data for (26.374299999999998, 50.1873)...
# Fetching data for (26.374299999999998, 50.2053)...
# Fetching data for (26.374299999999998, 50.2233)...
# Fetching data for (26.374299999999998, 50.2413)...
# Fetching data for (26.374299999999998, 50.259299999999996)...
# Fetching data for (26.3923, 50.0073)...
# Fetching data for (26.3923, 50.0253)...
# Fetching data for (26.3923, 50.0433)...
# Fetching data for (26.3923, 50.061299999999996)...
# Fetching data for (26.3923, 50.079299999999996)...
# Fetching data for (26.3923, 50.0973)...
# Fetching data for (26.3923, 50.1153)...
# Fetching data for (26.3923, 50.1333)...
# Fetching data for (26.3923, 50.1513)...
# Fetching data for (26.3923, 50.1693)...
# Fetching data for (26.3923, 50.1873)...
# Fetching data for (26.3923, 50.2053)...
# Fetching data for (26.3923, 50.2233)...
# Fetching data for (26.3923, 50.2413)...
# Fetching data for (26.3923, 50.259299999999996)...
# Fetching data for (26.4103, 50.0073)...
# Fetching data for (26.4103, 50.0253)...
# Fetching data for (26.4103, 50.0433)...
# Fetching data for (26.4103, 50.061299999999996)...
# Fetching data for (26.4103, 50.079299999999996)...
# Fetching data for (26.4103, 50.0973)...
# Fetching data for (26.4103, 50.1153)...
# Fetching data for (26.4103, 50.1333)...
# Fetching data for (26.4103, 50.1513)...
# Fetching data for (26.4103, 50.1693)...
# Fetching data for (26.4103, 50.1873)...
# Fetching data for (26.4103, 50.2053)...
# Fetching data for (26.4103, 50.2233)...
# Fetching data for (26.4103, 50.2413)...
# Fetching data for (26.4103, 50.259299999999996)...
# ✅ Data collection complete! Check the CSV files.
