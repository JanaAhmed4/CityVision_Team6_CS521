# %%
import numpy as np
import pandas as pd

from tabulate import tabulate

file_path = "saudi_population.csv"  
df = pd.read_csv(file_path)
df
# Out:
#        Unnamed: 0  main_id             gid  level                     area  \
# 0               0    36546  12341414432441     14  400 meters x 400 meters
# 1               1    36547  12341423331311     14  400 meters x 400 meters
# 2               2    36550  13232443132133     14  400 meters x 400 meters
# 3               3    37022  11434333141443     14  400 meters x 400 meters
# 4               4    35751  12333312231434     14  400 meters x 400 meters
# ...           ...      ...             ...    ...                      ...
# 82570       82570  1420062  13213423323323     14  400 meters x 400 meters
# 82571       82571  1420065  13213423441141     14  400 meters x 400 meters
# 82572       82572  1420070  13213421141341     14  400 meters x 400 meters
# 82573       82573  1416420  11443124121211     14  400 meters x 400 meters
# 82574       82574  1416431  13243411412334     14  400 meters x 400 meters
#
# ...
